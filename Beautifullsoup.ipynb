# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
html_file=requests.get("https://www.google.com/search?q=clothing+brands&rlz=1C1VDKB_en-GBGB1108GB1108&oq=clo&gs_lcrp=EgZjaHJvbWUqDggAEEUYJxg7GIAEGIoFMg4IABBFGCcYOxiABBiKBTIGCAEQRRg5MhAIAhAuGMcBGLEDGNEDGIAEMgcIAxAAGIAEMhAIBBAuGMcBGLEDGNEDGIAEMgYIBRBFGDwyBggGEEUYPDIGCAcQRRg80gEINjM0OGowajeoAgCwAgA&sourceid=chrome&ie=UTF-8").text

# %%
soup=BeautifulSoup(html_file,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><style nonce="pC7EjbaBlCE-Hh46b3hQ4Q">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 800px;
#   padding: 24px;
# }
# .youtubeContainerUIModernization,
# .boxUIModernization {
#   box-sizing: border-box;
#   margin-left: auto;
#   margin-right: auto;
#   max-width: 800px;
# }
# .signInContainerUIModernization {
#     display: flex;
#     justify-content: flex-end;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# .icaCallout {
#   background-color: #f8f9fa;
#   padding: 12px 16px;
#   border-radius: 10px;
# ...

# %%
cloth=soup.find_all('div',class_="RnJeZd top pla-unit-title")
# Out:
# []

# %%
price=[]
for i in soup.find_all('div',class_="Gor6zc JtzP6"):
    print(i)#price.append(i.text)
#price
# Out:
# []

# %%
p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 price.text
#
# AttributeError: 'list' object has no attribute 'text'
